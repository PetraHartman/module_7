# %% [markdown]
# # text assignment CO2

# %% [markdown]
# This is your final assignment. You'll get a lot of freedom in doing this assignment but that also means you have to make choices and explain the reasoning behind those choices in your report.
#
#
# For this assignment you can use any dataset you can find from the [Our World in Data website](https://ourworldindata.org/)
#
# Please formulate an answer to the following three questions in your report.
#
# 1. What is the biggest predictor of a large CO2 output per capita of a country?
# 2. which countries are making the biggest strides in decreasing CO2 output?
# 3. which non-fossil fuel energy technology will have the best price in the future?
#
#
# 1. Biggest predictor of CO2 output
#
# To determine this you may want to consider things like GDP per capita, diets, number of cars per capita, various energy source, mobility and other factors.
#
# Your answer can also be a specific combination of certain factors.
#
#
# 2. Biggest strides in decreasing CO2 output
#
# You'll need to find the relative CO2 output for each country to be able to calculate this. But countries can have growing and shrinking populations too, so it's probably a good idea to take this into account as well.
#
#
# 3. Best future price for non-fossil fuel energy
#
# To be able to predict prices you'll probably need to use linear regression over the various non-fossil fuel options.

# %% [markdown]
# # Note
#
# There are no titles embedded in the code of the graphs. This is done because they would interfere in the final PDF report. Instead in the code there is a line with a description of the graph.

# %% [markdown]
# # Installations

# %%
pip install fpdf
# Out:
# Requirement already satisfied: fpdf in c:\users\petra\appdata\local\programs\python\python311\lib\site-packages (1.7.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # imports

# %%
import numpy as np
import numpy.polynomial.polynomial as poly # import voor regressielijn
from functools import reduce
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import patches as mpatches
from matplotlib.mathtext import FontProperties
from matplotlib.layout_engine import ConstrainedLayoutEngine
import missingno as msno
import sklearn.linear_model as skl
from sklearn.impute import KNNImputer # import voor KNN imputation
from sklearn.cluster import KMeans
from fpdf import FPDF
from scipy.stats import pearsonr
from scipy.stats import shapiro
from scipy.stats import lognorm

# %% [markdown]
# # Dataframe

# %% [markdown]
# ## Raw dataframes

# %%
url_co2_data = "https://raw.githubusercontent.com/PetraHartman/module_7/main/owid-co2-data.csv"
df_co2_data = pd.read_csv(url_co2_data, encoding = "iso-8859-1")

# %%
url_energy_cost = "https://raw.githubusercontent.com/PetraHartman/module_7/main/levelized-cost-of-energy.csv"
df_energy_cost = pd.read_csv(url_energy_cost, encoding = "iso-8859-1")

# %% [markdown]
# ## Modified/ cleaned dataframes

# %% [markdown]
# ### 1.What is the biggest predictor of a large CO2 output per capita of a country?

# %% [markdown]
# #### Create dataframe with desired structure

# %%
# keep columns from df_co2_data
capita_columns = [col for col in df_co2_data if "capita" in col]
df_co2_data_predictor_a = df_co2_data[["country",
                                       "year",
                                       "iso_code",
                                       "gdp",
                                       "population"]]
df_co2_data_predictor_b = df_co2_data[capita_columns]
df_predictor = pd.concat([df_co2_data_predictor_a, df_co2_data_predictor_b],
                               axis = 1)

# capitalize column names
df_predictor.columns = [s.capitalize() for s in df_predictor.columns]

# change column names
df_predictor.columns = df_predictor.columns.str.replace("_", " ")
df_predictor.columns = df_predictor.columns.str.replace("per capita", "(per capita)")
df_predictor.columns = df_predictor.columns.str.replace("co2", "CO2")
df_predictor.columns = df_predictor.columns.str.replace("Co2", "CO2")

# add gdp per catipa
if "GDP (per capita)" not in df_predictor:
   df_predictor['GDP (per capita)'] = df_predictor["Gdp"] / df_predictor["Population"]

# drop columns because combined are CO2 including luc (per capita)
df_predictor = df_predictor.drop("CO2 (per capita)", axis = 1)
df_predictor = df_predictor.drop("Land use change CO2 (per capita)", axis = 1)
# drop column because is similar to Ghg (per capita)
df_predictor = df_predictor.drop("Ghg excluding lucf (per capita)", axis = 1)

# drop columns that have been recalcutated to (per capita)
df_predictor = df_predictor.drop("Gdp", axis = 1)

# rename column to clarify name
df_predictor = df_predictor.rename(columns = {"Other CO2 (per capita)" : "Other industries CO2 (per capita)" })

# drop NaN values
df_predictor = df_predictor.dropna()

# %% [markdown]
# #### Determine desired period of time.
#
# The data can be better compared if all countries contributing data are equal over the analized period.

# %%
def contributing_countries_predictor():
    year_list = pd.unique(df_predictor["Year"])
    grp_data = df_predictor.groupby(["Year"])
    df_contributing = pd.DataFrame(columns = ["Year",
                                              "Number of data contributing countries"])
    for year in year_list:
        if year not in df_contributing:
           length = len (grp_data.get_group(year))

           row = {"Year" : [year],
                  "Number of data contributing countries" : [length]}
           df_row = pd.DataFrame(row)
           df_contributing = pd.concat([df_contributing, df_row], axis = 0)

           df_contributing["Number of data contributing countries"] = df_contributing["Number of data contributing countries"].astype(int)
    return (df_contributing)

df_year_prediction = contributing_countries_predictor()

# %%
# max number of data contributing countries
max_countries_year = df_year_prediction["Number of data contributing countries"].max()
df_year_prediction = df_year_prediction.loc[df_year_prediction["Number of data contributing countries"] ==
                                            df_year_prediction["Number of data contributing countries"].max()]

# First and last year with maximum data contributing countries
first_year = df_year_prediction["Year"].min()
last_year = df_year_prediction["Year"].max()

# list of all countries in years of maximum contributing countries
df_predictor= df_predictor.loc[(df_predictor["Year"] <= df_year_prediction["Year"].max()) &
                               (df_predictor["Year"] >= df_year_prediction["Year"].min())]

# number of unique countries in years of maximum data contributing countries
unique_country_list = []
for country in df_predictor["Country"]:
    if country not in unique_country_list:
       unique_country_list.append(country)
# len(unique_country_list) == df_year["Number of data contributing countries"].max()

f"""Each year from {first_year} till {last_year} consists out of the same {max_countries_year} data contributing countries."""
# Out:
# 'Each year from 2003 till 2018 consists out of the same 43 data contributing countries.'

# %% [markdown]
# #### Set dataframe to desired time frame.
#
# Filter df_predictor to only the years where the max number of countries contributed in the data.
# The assumption is made that all deliver the data unther the same conditions.

# %%
mask_year = df_predictor.Year >= first_year
df_predictor = df_predictor[mask_year]

# %% [markdown]
# #### Identify outliers

# %% [markdown]
# Determine mean for each variable

# %%
# Make list of mean for each data variable.
df = df_predictor
column_names = [col for col in df.columns if "capita" in col]
df_predictor_mean = pd.DataFrame(columns = ["Variable"])

for column_name in column_names:
    # calculate mean
    mean = round(df[column_name].mean(),4)
    row = {"Variable": [column_name],
           "Mean" : [mean]}
    df_row = pd.DataFrame(row)
    df_predictor_mean = pd.concat([df_predictor_mean, df_row], axis = 0)

display(df_predictor_mean)
# Out:
#                             Variable        Mean
# 0            Cement CO2 (per capita)      0.2231
# 0     CO2 including luc (per capita)      8.8002
# 0              Coal CO2 (per capita)      2.6917
# 0       Consumption CO2 (per capita)     10.1935
# 0                Energy (per capita)  46145.8045
# 0           Flaring CO2 (per capita)      0.0965
# 0               Gas CO2 (per capita)      1.9423
# 0                   Ghg (per capita)      9.6256
# 0               Methane (per capita)      1.4626
# 0         Nitrous oxide (per capita)      0.7567
# 0               Oil CO2 (per capita)      3.6140
# 0  Other industries CO2 (per capita)      0.0958
# 0                   GDP (per capita)  31032.4992

# %% [markdown]
# Determine outliers by IQR and replace by mean value

# %%
df = df_predictor
column_names = [col for col in df.columns if "capita" in col]

for column_name in column_names:
    # calcultate upper and lower limits
    q_1 = np.percentile(df[column_name], 25, method = "midpoint")
    q_3 = np.percentile(df[column_name], 75, method = "midpoint")

    iqr = q_3 - q_1

    upper = round(q_3 + 1.5 * iqr, 4)
    lower = round(q_1 - 1.5 * iqr, 4)

    # determine outliers
    lower_array = list (np.where(df[column_name] <= lower) [0])
    upper_array = list(np.where(df[column_name] >= upper) [0])
    outlier_list = lower_array + upper_array

    # find mean from df_predictor_mean
    value_index = np.where(df_predictor_mean["Variable"] == column_name)
    mean_row = df_predictor_mean.iloc[value_index]
    mean = mean_row.iloc[0,1]

    for item in outlier_list:
        change_value = df[column_name].iloc[item]
        df[column_name] = df[column_name].replace({change_value : mean})

display(df_predictor)
# Out:
#              Country  Year Iso code   Population  Cement CO2 (per capita)  \
# 3751       Australia  2003      AUS   19699004.0                    0.182
# 3752       Australia  2004      AUS   19925060.0                    0.178
# 3753       Australia  2005      AUS   20171732.0                    0.182
# 3754       Australia  2006      AUS   20467032.0                    0.190
# 3755       Australia  2007      AUS   20830832.0                    0.191
# ...              ...   ...      ...          ...                      ...
# 48151  United States  2014      USA  322033952.0                    0.122
# 48152  United States  2015      USA  324607776.0                    0.123
# 48153  United States  2016      USA  327210208.0                    0.121
# 48154  United States  2017      USA  329791232.0                    0.122
# 48155  United States  2018      USA  332140032.0                    0.117
#
#        CO2 including luc (per capita)  Coal CO2 (per capita)  \
# 3751                           8.8002                 2.6917
# 3752                           8.8002                 2.6917
# 3753                           8.8002                 2.6917
# 3754                           8.8002                 2.6917
# 3755                           8.8002                 2.6917
# ...                               ...                    ...
# 48151                         17.2710                 5.3110
# 48152                         16.6330                 4.5560
# 48153                         16.2370                 4.1190
# 48154                         16.0010                 3.9680
# 48155                         16.4320                 3.7820
#
#        Consumption CO2 (per capita)  Energy (per capita)  \
# 3751                         16.993            69082.789
# 3752                         17.292            70486.320
# 3753                         17.051            69917.164
# 3754                         17.410            71863.758
# 3755                         17.677            72304.695
# ...                             ...                  ...
# 48151                        18.142            80725.086
# 48152                        17.852            79317.367
# 48153                        17.310            78613.539
# 48154                        17.088            78289.008
# 48155                        17.477            80583.344
#
#        Flaring CO2 (per capita)  Gas CO2 (per capita)  Ghg (per capita)  \
# 3751                     0.0965                 2.523            9.6256
# 3752                     0.0965                 2.636            9.6256
# 3753                     0.0965                 2.701            9.6256
# 3754                     0.0965                 2.727            9.6256
# 3755                     0.0965                 2.931            9.6256
# ...                         ...                   ...               ...
# 48151                    0.1990                 4.456           17.9470
# 48152                    0.2010                 4.547           17.4520
# 48153                    0.1670                 4.528           17.5540
# 48154                    0.1800                 4.428           17.2520
# 48155                    0.0965                 4.874           17.7410
#
#        Methane (per capita)  Nitrous oxide (per capita)  Oil CO2 (per capita)  \
# 3751                 1.4626                      0.7567                 5.562
# 3752                 1.4626                      0.7567                 5.710
# 3753                 1.4626                      0.7567                 5.776
# 3754                 1.4626                      0.7567                 5.736
# 3755                 1.4626                      0.7567                 5.735
# ...                     ...                         ...                   ...
# 48151                2.0820                      0.8140                 6.979
# 48152                2.0690                      0.8040                 7.040
# 48153                1.9960                      0.8170                 7.028
# 48154                2.0310                      0.8100                 7.019
# 48155                1.4626                      0.8090                 7.121
#
#        Other industries CO2 (per capita)  GDP (per capita)
# 3751                               0.198      39284.657119
# 3752                               0.196      40623.201889
# 3753                               0.193      41669.925910
# 3754                               0.188      42450.659090
# 3755                               0.196      43871.308717
# ...                                  ...               ...
# 48151                              0.101      51182.996422
# 48152                              0.096      52070.775112
# 48153                              0.088      52451.166787
# 48154                              0.084      53355.826875
# 48155                              0.074      54617.462728
#
# [688 rows x 17 columns]

# %% [markdown]
# #### Normality check

# %% [markdown]
# Looking if data is distributed normal. This is done with the Shapiro wilk test. If the Shapiro Wilk test gives a P-value smaller than 0.05 the data is not distributed normal.

# %%
def shapiro_wilk():
  capita_columns = [col for col in df_predictor if "capita" in col]
  df_normal = pd.DataFrame(columns = ["Variable"])
  for name in capita_columns:  # takes all columns except for "Population"
      a = df_predictor[capita_columns[0]]
      b = df_predictor[name]
      shapiro_wilk = shapiro(b)
      shapiro_value = shapiro_wilk[0]
      p_value = shapiro_wilk[1]

      if p_value < 0.05:  # if p-value is smaller than 0.05 the data is not distributed normal.
         normal = "No"
      else:
         normal = "Yes"
      row = {"Variable" : name,
             "Shapiro" : shapiro_value,
             "P-value" : p_value,
             "Normal distributed": normal}
      df_row = pd.DataFrame(row, index=[0])
      df_normal = pd.concat([df_normal, df_row])
  if "Population" in df_predictor:  # taken seperately for there is no "capita" in the description.
     a = df_predictor[capita_columns[0]]
     b = df_predictor["Population"]
     shapiro_wilks = shapiro(b)
     shapiro_value = shapiro_wilks[0]
     p_value = shapiro_wilks[1]

     if p_value < 0.05:  # if p-value is smaller than 0.05 the data is not distributed normal.
        normal = "No"
     else:
        normal = "Yes"
     row = {"Variable" : "Population",
            "Shapiro" : shapiro_value,
            "P-value" : p_value,
            "Normal distributed": normal}
     df_row = pd.DataFrame(row, index=[0])
     df_normal = pd.concat([df_normal, df_row])
  return(df_normal)

df_shapiro = shapiro_wilk()
display(df_shapiro)
# Out:
#                             Variable   Shapiro       P-value  \
# 0            Cement CO2 (per capita)  0.980538  6.313118e-08
# 0     CO2 including luc (per capita)  0.967509  3.209672e-11
# 0              Coal CO2 (per capita)  0.910336  1.046196e-19
# 0       Consumption CO2 (per capita)  0.963302  4.231827e-12
# 0                Energy (per capita)  0.967618  3.390536e-11
# 0           Flaring CO2 (per capita)  0.877033  6.975323e-23
# 0               Gas CO2 (per capita)  0.960572  1.231572e-12
# 0                   Ghg (per capita)  0.975659  2.777848e-09
# 0               Methane (per capita)  0.961851  2.179588e-12
# 0         Nitrous oxide (per capita)  0.945643  3.398593e-15
# 0               Oil CO2 (per capita)  0.963258  4.146189e-12
# 0  Other industries CO2 (per capita)  0.969286  7.948688e-11
# 0                   GDP (per capita)  0.973370  7.302980e-10
# 0                         Population  0.299409  5.605194e-45
#
#   Normal distributed
# 0                 No
# 0                 No
# 0                 No
# 0                 No
# 0                 No
# 0                 No
# 0                 No
# 0                 No
# 0                 No
# 0                 No
# 0                 No
# 0                 No
# 0                 No
# 0                 No

# %% [markdown]
# #### Normalizing data

# %% [markdown]
# Since non of the data is distributed normal. The data needs to be normalized.
# This is done by taking the cubic root of the data.

# %%
# normalize data by cubic root
capita_columns = [col for col in df_predictor if "capita" in col]
df_predictor_normalized = pd.DataFrame(columns =[])
for name in capita_columns:
    df_predictor_normalized[name] = np.cbrt(df_predictor[name])
df_predictor_normalized["Population"] = np.cbrt(df_predictor["Population"])
display(df_predictor_normalized)
# Out:
#        Cement CO2 (per capita)  CO2 including luc (per capita)  \
# 3751                  0.566705                        2.064576
# 3752                  0.562523                        2.064576
# 3753                  0.566705                        2.064576
# 3754                  0.574890                        2.064576
# 3755                  0.575897                        2.064576
# ...                        ...                             ...
# 48151                 0.495968                        2.584873
# 48152                 0.497319                        2.552644
# 48153                 0.494609                        2.532223
# 48154                 0.495968                        2.519895
# 48155                 0.489097                        2.542320
#
#        Coal CO2 (per capita)  Consumption CO2 (per capita)  \
# 3751                1.391048                      2.570929
# 3752                1.391048                      2.585920
# 3753                1.391048                      2.573850
# 3754                1.391048                      2.591789
# 3755                1.391048                      2.604971
# ...                      ...                           ...
# 48151               1.744719                      2.627615
# 48152               1.657784                      2.613539
# 48153               1.602989                      2.586817
# 48154               1.583157                      2.575711
# 48155               1.558023                      2.595109
#
#        Energy (per capita)  Flaring CO2 (per capita)  Gas CO2 (per capita)  \
# 3751             41.032057                  0.458679              1.361358
# 3752             41.308074                  0.458679              1.381386
# 3753             41.196590                  0.458679              1.392649
# 3754             41.575420                  0.458679              1.397103
# 3755             41.660278                  0.458679              1.431106
# ...                    ...                       ...                   ...
# 48151            43.218482                  0.583827              1.645565
# 48152            42.965786                  0.585777              1.656692
# 48153            42.838322                  0.550688              1.654381
# 48154            42.779292                  0.564622              1.642111
# 48155            43.193172                  0.458679              1.695490
#
#        Ghg (per capita)  Methane (per capita)  Nitrous oxide (per capita)  \
# 3751           2.127205              1.135120                    0.911258
# 3752           2.127205              1.135120                    0.911258
# 3753           2.127205              1.135120                    0.911258
# 3754           2.127205              1.135120                    0.911258
# 3755           2.127205              1.135120                    0.911258
# ...                 ...                   ...                         ...
# 48151          2.618167              1.276910                    0.933702
# 48152          2.593871              1.274247                    0.929862
# 48153          2.598915              1.259081                    0.934847
# 48154          2.583924              1.266397                    0.932170
# 48155          2.608111              1.135120                    0.931786
#
#        Oil CO2 (per capita)  Other industries CO2 (per capita)  \
# 3751               1.771782                           0.582848
# 3752               1.787360                           0.580879
# 3753               1.794220                           0.577900
# 3754               1.790069                           0.572865
# 3755               1.789965                           0.580879
# ...                     ...                                ...
# 48151              1.911016                           0.465701
# 48152              1.916568                           0.457886
# 48153              1.915478                           0.444796
# 48154              1.914660                           0.437952
# 48155              1.923890                           0.419834
#
#        GDP (per capita)  Population
# 3751          33.994422  270.073158
# 3752          34.376214  271.102307
# 3753          34.668968  272.216469
# 3754          34.884150  273.538392
# 3755          35.269031  275.149591
# ...                 ...         ...
# 48151         37.128600  685.436490
# 48152         37.342038  687.257740
# 48153         37.432749  689.089472
# 48154         37.646732  690.896567
# 48155         37.941151  692.532896
#
# [688 rows x 14 columns]

# %% [markdown]
# An example of the original versus the normalized data  for the "CO2 including luc (per capita). Be aware that normalized data does not have to match the normal distribution, but is coming close(r) to the normal distribution.

# %%
display("""Example of original and normalized data ("Coal CO2 (per capita)")""")

example_predictor_original = df_predictor["Coal CO2 (per capita)"]
example_predictor_normalized = df_predictor_normalized["Coal CO2 (per capita)"]

fig, ax = plt.subplots(nrows = 1, ncols = 2)

ax[0].hist(example_predictor_original)
ax[1].hist(example_predictor_normalized)
ax[0].set_title("Original data")
ax[1].set_title("Normalized data")
plt.savefig("histograms_original_normalized.png", transparent = False, facecolor = "white", bbox_inches = "tight")
# Out:
# 'Example of original and normalized data ("Coal CO2 (per capita)")'

# %% [markdown]
# ### 2.Which countries are making the biggest strides in decreasing CO2 output?

# %% [markdown]
# #### Create dataframe with desired structure

# %%
# kept iso_code column so I could filter out nan (not countries.)
df_co2_reduction = df_co2_data[["country",
                                "iso_code",
                                "year",
                                "population",
                                "co2"]]

# drop NaN
df_co2_reduction = df_co2_reduction.dropna()

# drop Iso code (not needed anymore)
df_co2_reduction = df_co2_reduction.drop("iso_code", axis = 1)

df_co2_reduction.columns
# Out:
# Index(['country', 'year', 'population', 'co2'], dtype='object')

# %% [markdown]
# #### Determine desired period of time.

# %%
def contributing_countries_reduction():
    year_list = pd.unique(df_co2_reduction["year"])
    grp_data = df_co2_reduction.groupby(["year"])
    df_contributing = pd.DataFrame(columns = ["Year",
                                          "Number of data contributing countries"])
    for year in year_list:
        if year not in df_contributing:
           length = len (grp_data.get_group(year))
           sum_co2 = grp_data.get_group(year)["co2"].sum(axis=0)

           row = {"Year" : [year],  "Total CO2 emissions" : [sum_co2], "Number of data contributing countries" : [length]}
           df_row = pd.DataFrame(row)
           df_contributing = pd.concat([df_contributing, df_row], axis = 0)

           df_contributing["Number of data contributing countries"]= df_contributing["Number of data contributing countries"].astype(int)
    return (df_contributing)

df_year_reduction = contributing_countries_reduction()
display(df_year_reduction)
# Out:
#     Year  Number of data contributing countries  Total CO2 emissions
# 0   1949                                    114             5245.832
# 0   1950                                    174             5873.200
# 0   1951                                    176             6225.068
# 0   1952                                    177             6307.820
# 0   1953                                    177             6484.139
# ..   ...                                    ...                  ...
# 0   1911                                     77             3079.218
# 0   1912                                     77             3235.540
# 0   1913                                     80             3505.870
# 0   1914                                     74             3179.913
# 0   1915                                     75             3134.378
#
# [227 rows x 3 columns]

# %%
def total_emission_year_graph():
    fig, ax = plt.subplots()
    ax1 = ax.twinx()
    ax.scatter(df_year_reduction["Year"], df_year_reduction["Total CO2 emissions"], color = "blue", marker = ".", label = "Total CO\u2082 emissions")
    ax1.scatter(df_year_reduction["Year"], df_year_reduction["Number of data contributing countries"], color = "red", marker = ".", label = "Number of data contributing countries")

    # ax.set_title("Total CO\u2082 emission per year")
    ax.set_xlabel("Year")
    ax.set_ylabel("CO\u2082 [million tons]")
    ax1.set_ylabel("Number of data contributing countries", rotation = -90, labelpad = 15)
    ax.xaxis.grid(True)

    lines, labels = ax.get_legend_handles_labels()
    lines2, labels2 = ax1.get_legend_handles_labels()
    ax1.legend(lines + lines2, labels + labels2, loc=0)

    return plt.savefig("total_emission_per_year.png", transparent = False, facecolor = "white", bbox_inches = "tight")

graph_total_emission_year = total_emission_year_graph()

# %%
# max number of data contributing countries
max_countries_year = df_year_reduction["Number of data contributing countries"].max()
df_year_reduction = df_year_reduction.loc[df_year_reduction["Number of data contributing countries"] == df_year_reduction["Number of data contributing countries"].max()]

first_year = df_year_reduction["Year"].min()
last_year = df_year_reduction["Year"].max()

# list of all countries in years of maximum contributing countries
df_reduction= df_co2_reduction.loc[(df_co2_reduction["year"] <= df_year_reduction["Year"].max()) &
                                   (df_co2_reduction["year"] >= df_year_reduction["Year"].min())]

# number of unique countries in years of maximum data contributing countries
unique_country_list = []
for country in df_reduction["country"]:
    if country not in unique_country_list:
       unique_country_list.append(country)
# display(len(unique_country_list) == df_info_year["Number of data contributing countries"].max())

f"""each year from {first_year} till {last_year} consists out of the same {max_countries_year} data contributing countries."""
# Out:
# 'each year from 2002 till 2021 consists out of the same 218 data contributing countries.'

# %% [markdown]
# #### Set dataframe to desired time frame
#
# Filter df_co2_reduction to only the years where 218 countries contributed in the data. The assumption is made that all deliver the data unther the same conditions.

# %%
mask_year = df_co2_reduction.year >= first_year
df_co2_reduction = df_co2_reduction[mask_year]

# %% [markdown]
# #### Identify outliers

# %% [markdown]
# IQR method

# %%
country_group = df_co2_reduction.groupby("country")

country = "Germany"
country_data = country_group.get_group(country)
q1 = np.percentile(country_data["co2"], 25, method = "midpoint")
q3 = np.percentile(country_data["co2"], 75, method = "midpoint")
iqr = q3 - q1

lower = q1 - 1.5 * iqr
upper = q3 + 1.5 * iqr

array_lower = list(np.where(country_data["co2"] <= lower)[0])
array_upper = list(np.where(country_data["co2"] >= upper)[0])

f"""Since the {len(array_lower) + len(array_upper)} datapoints marked as outliers are valid data because of the CO2 reduction achieved by {country}, but marked as outliers by the IQR method, it is not possible to descard of the outliers in the dataset by IQR."""
# Out:
# 'Since the 2 datapoints marked as outliers are valid data because of the CO2 reduction achieved by Germany, but marked as outliers by the IQR method, it is not possible to descard of the outliers in the dataset by IQR.'

# %% [markdown]
# Identify outliers by Z-score method

# %% [markdown]
# Check if valid datapoints of Germany don't become outliers.

# %%
country_group = df_co2_reduction.groupby("country")
country = "Germany"
country_data = country_group.get_group(country)

mean = country_data["co2"].mean()
std = country_data["co2"].std()

# calculate Z score, if Z score > 3 it is an outlier
treshold = 3
outlier = []
for i in country_data["co2"]:
    z = (i-mean)/std
    if z > treshold:
      outlier.append(i)

print ("outlier in dataset", outlier)
print ("The Z-score method can be used for removing outliers from this dataset")
# Out:
# outlier in dataset []
# The Z-score method can be used for removing outliers from this dataset

# %% [markdown]
# find mean CO2 for each country

# %%
# Make list of mean for each data variable.
df = df_co2_reduction
country_group = df.groupby("country")
country_list = df.country.unique()
df_co2_mean = pd.DataFrame(columns = ["Country"])

for country in country_list:
    country_data = country_group.get_group(country)
# calculate mean
    mean = country_data["co2"].mean()
    std = country_data["co2"].std()
    row = {"Country": [country],
           "Mean" : [mean],
           "Std" : [std]}
    df_row = pd.DataFrame(row)
    df_co2_mean = pd.concat([df_co2_mean, df_row], axis = 0)

display(df_co2_mean)
# Out:
#               Country       Mean        Std
# 0         Afghanistan    7.22375   4.041831
# 0             Albania    4.67880   0.572531
# 0             Algeria  133.27015  31.961441
# 0             Andorra    0.50260   0.038422
# 0              Angola   22.86535   5.180118
# ..                ...        ...        ...
# 0             Vietnam  173.96410  88.317127
# 0   Wallis and Futuna    0.02610   0.002447
# 0               Yemen   17.99200   5.359090
# 0              Zambia    4.31160   2.135264
# 0            Zimbabwe   10.49945   1.258556
#
# [218 rows x 3 columns]

# %%
# find all outliers in dataframe
df = df_co2_reduction
country_group = df.groupby("country")

country_list = df.country.unique()
df_outlier = pd.DataFrame(columns = ["Country"])
for country in country_list:
    # find mean and std
    value_index = np.where(df_co2_mean["Country"] == country)
    value_row = df_co2_mean.iloc[value_index]
    mean = value_row.iloc[0,1]
    std = value_row.iloc[0,2]

    country_data = country_group.get_group(country)
    # calculate Z score, if Z score > 3 it is an outlier
    treshold = 3
    for i in country_data["co2"]:
        z = round((i-mean)/std, 2)
        # als datapunt boven z waarde datapunt met extra's toevoegen aan df_outlier.
        if z > treshold:
          row = {"Country": [country],
                 "Mean" : [mean],
                 "Std" : [std],
                 "co2" : [i],
                 "z": [z]}
          df_row = pd.DataFrame(row)
          df_outlier = pd.concat([df_outlier, df_row], axis = 0)
display(df_outlier)

# country = df_outlier["Country"].iloc[0]
country = "Germany"
value = df_outlier["co2"].iloc[0]
mean = df_outlier["Mean"].iloc[0]

# find mean from df_c02_reduction
value_index = np.where(df_co2_reduction["co2"] == value)
value_row = df_co2_reduction["co2"].iloc[value_index[0]]
# replace single value for mean
df_co2_reduction.iloc[value_index[0], 3] = mean
# Out:
#     Country    Mean      Std  co2     z
# 0  Eswatini  1.0395  0.11943  1.4  3.02

# %% [markdown]
# The IQR is not possible for filtering outliers. At first I worked with the rolling mean, but than learned (after consultation) about the Z-score method.
# Since the Z-score method worked, the rolling mean is not used anymore. However, on advise I kept the code here.

# %%
# country_group = df_co2_reduction.groupby("country")
# rolling_data = pd.DataFrame(columns = ["country"])

# country_list = []
# for country in df_co2_reduction["country"]:
#   unique_country_list = []
#   if country not in unique_country_list:
#     country_list.append(country)

# for country in country_list:
#     country_data = country_group.get_group(country)
#     rolling_country_data = pd.DataFrame(columns = ["country"])
#     rolling_country_data = pd.concat([rolling_country_data, country_data], axis = 0)
#     rolling_country_data["co2_rolling"] = rolling_country_data["co2"].rolling(3).mean()
#     rolling_country_data["co2_capita_rolling"] = rolling_country_data["co2_rolling"]/rolling_country_data["population"] * 1000000 # in ton CO2
#     rolling_country_data = rolling_country_data.dropna()
#     rolling_data = pd.concat([rolling_country_data, rolling_data], axis = 0)

# df_co2_reduction = rolling_data
# df_co2_reduction = df_co2_reduction.drop("co2", axis = 1)
# df_co2_reduction

# %% [markdown]
# No normality check is needed for the analyses performed

# %% [markdown]
# ### 3.Which non-fossil fuel energy technology will have the best price in the future?

# %% [markdown]
# #### Create dataframe with desired structure
#
# Seen the shape and size of data, no outliertest is performed.

# %%
df_energy_cost = df_energy_cost.sort_values(by = ["Year"])
# display(df_energy_cost)
df_energy_cost_world = df_energy_cost.groupby("Entity").get_group("World")
# display(df_energy_cost_world)

# %% [markdown]
# # Analysis

# %% [markdown]
# ## 1.What is the biggest predictor of a large CO2 output per capita of a country?

# %% [markdown]
# ### Determine correlation
#
# Test for correlation between CO2 including luc (per capita) and other datasets, by Person r method. Normalized data is used.

# %%
# find correlation between total co2 per capita and parts of total co2 per capita
capita_columns = [col for col in df_predictor_normalized if "capita" in col]

df_pearsonr = pd.DataFrame(columns = ["Variable", "Pearsonr", "P-value"])

# for relevant columns with capita in the name
for column in capita_columns:
    pearson_r_value = pearsonr(df_predictor_normalized["CO2 including luc (per capita)"], df_predictor_normalized[column])
    n = len(df_predictor_normalized[column])
    row = {"Variable" : column,
           "Pearsonr" : pearson_r_value[0],
           "P-value" : pearson_r_value[1],
           "N" : n}
    df_row = pd.DataFrame(row, index = [0])
    df_pearsonr = pd.concat([df_pearsonr, df_row])

# for population (has no capita in column name)
pearson_r_value = pearsonr(df_predictor_normalized["CO2 including luc (per capita)"], df_predictor_normalized["Population"])
n = len(df_predictor_normalized["Population"])
row = {"Variable" : "Population",
       "Pearsonr" : pearson_r_value[0],
       "P-value" : pearson_r_value[1],
       "N" : n}
df_row = pd.DataFrame(row, index = [0])
df_pearsonr = pd.concat([df_pearsonr, df_row])

# drop column CO2 including luc (per capita) since this is the reference
df_pearsonr = df_pearsonr[(df_pearsonr.Variable != "CO2 including luc (per capita)")]

# only use significant values (P>0.05) and sort descending
df_pearsonr = df_pearsonr[df_pearsonr["P-value"] <0.05].sort_values("Pearsonr", ascending = False)

display (df_pearsonr)
# Out:
#                             Variable  Pearsonr       P-value      N
# 0                Energy (per capita)  0.604152  1.129442e-69  688.0
# 0                   Ghg (per capita)  0.562728  1.027533e-58  688.0
# 0       Consumption CO2 (per capita)  0.537872  7.559754e-53  688.0
# 0              Coal CO2 (per capita)  0.509471  1.022118e-46  688.0
# 0  Other industries CO2 (per capita)  0.453625  3.198785e-36  688.0
# 0               Oil CO2 (per capita)  0.397458  1.852783e-27  688.0
# 0                   GDP (per capita)  0.379878  4.845908e-25  688.0
# 0               Gas CO2 (per capita)  0.309410  9.926336e-17  688.0
# 0               Methane (per capita)  0.240322  1.703339e-10  688.0
# 0                         Population  0.146425  1.159632e-04  688.0
# 0         Nitrous oxide (per capita)  0.120567  1.533552e-03  688.0
# 0           Flaring CO2 (per capita)  0.080555  3.464195e-02  688.0

# %% [markdown]
# ### Visualize correlation between CO2 including luc (per capita) and other variables.

# %%
fig, ax = plt.subplots()

side_text_distance = len(df_pearsonr["Variable"]) + 0.5

reverence = df_pearsonr ["Variable"]
pearsonr_values = df_pearsonr["Pearsonr"]
ax.bar(reverence, pearsonr_values)
plt.xticks(rotation = 45, ha = "right", rotation_mode = "anchor")

ax.set_ylabel("Pearson coefficient")
# ax.set_title("Correlating factors for a high CO2 output")
ax.set_ylim(0,1)


plt.axhline(y=0.1, color="red", linestyle="--")  # border between little/ no correlation and weak correlation
plt.axhline(y=0.3, color="red", linestyle="--")  # border between week correlation and medium correlation
plt.axhline(y=0.5, color="red", linestyle="--")  # border between medium correlation and strong correlation
ax.spines["right"].set_color("red")
ax.spines["bottom"].set_color("red")

plt.text(side_text_distance, 0.05, "Little or no correlation", fontsize = 9)
plt.text(side_text_distance, 0.2, "Weak correlation", fontsize = 9)
plt.text(side_text_distance, 0.4, "Medium correlation", fontsize = 9)
plt.text(side_text_distance, 0.75, "Strong correlation", fontsize = 9)

plt.savefig("correlating_factors.png", transparent = False, facecolor = "white", bbox_inches = "tight")

# %% [markdown]
# ### Top 3 predicting variables.

# %%
# top 3 correlating factors for a high CO2 output are:
correlating_factor_1 = df_pearsonr.iloc[1, 0]
correlating_factor_2 = df_pearsonr.iloc[2, 0]
correlating_factor_3 = df_pearsonr.iloc[3, 0]
display(correlating_factor_1, correlating_factor_2, correlating_factor_3)
# Out:
# 'Ghg (per capita)'
# 'Consumption CO2 (per capita)'
# 'Coal CO2 (per capita)'

# %% [markdown]
# ## 2.which countries are making the biggest strides in decreasing CO2 output?

# %% [markdown]
# Calculating CO2 difference per country over the period all countries contributed data.

# %% [markdown]
# ### Calculate co2 difference
#
#
# after feedback from first correction, i changed the calculation from co2 max to co2 start to calculate reduction.

# %%
def co2_difference ():
    df_co2_reduction.sort_values(by = "year")

    country_group = df_co2_reduction.groupby("country")
    df_co2_difference = pd.DataFrame(columns = ["Country",
                                                "CO2 difference [%]",
                                                "CO2 difference per capita [%]"])
    country_list = df_co2_reduction.country.unique()
    df_co2_reduction["co2_capita"] = (df_co2_reduction["co2"]/df_co2_reduction["population"])
    for country in country_list:
        country_data = country_group.get_group(country)

        year_start = country_data["year"].iloc[0]  # Year of first measurement
        start_co2 = country_data["co2"].iloc[0]
        year_end = country_data["year"].iloc[-1]  # Year of last measurement
        pop_start = country_data["population"].iloc[0]  # Population in year of first measurement
        pop_end = country_data["population"].iloc[-1]  # Population in year of last measurement
        end_co2 = country_data["co2"].tail(1)  # Last meaurement for CO2 output
        difference_co2 = (end_co2 - start_co2) / end_co2 * 100  # Percentage of difference in output between the start value and the last measured value
        start_co2_capita = country_data["co2_capita"].iloc[0]  # First meaurement for CO2 output per capita
        end_co2_capita = country_data["co2_capita"].iloc[-1]  # Last meaurement for CO2 output per capita
        difference_co2_capita = (end_co2_capita - start_co2_capita) / end_co2_capita * 100  # Percentage of difference in output per capita between the start value and the last measured value
        difference_pop = (pop_end - pop_start)/ pop_end * 100  # Percentage of difference in population

        row = {"Country": country,
               "Population change [%]": difference_pop,
               "CO2 difference [%]" : difference_co2,
               "CO2 difference per capita [%]" : difference_co2_capita}
        df_row = pd.DataFrame(row)
        df_co2_difference = pd.concat([df_co2_difference, df_row], axis = 0)
    return(df_co2_difference)

df_co2_difference = co2_difference()

# %% [markdown]
# The IQR is not possible for filtering outliers. At first I worked with the rolling mean, but than learned (after consultation) about the Z-score method.
# Since the Z-score method worked, the rolling mean is not used anymore. However, on advise I kept the code here.

# %%
# def co2_difference ():
#     df_co2_reduction.sort_values(by="year")

#     country_group = df_co2_reduction.groupby("country")
#     df_co2_difference = pd.DataFrame(columns = ["Country",
#                                                 "CO2 difference [%]",
#                                                 "CO2 difference per capita [%]"
#                                                 ])
#     country_list = df_co2_reduction.country.unique()

#     for country in country_list:
#         country_data = country_group.get_group(country)

#         year_start = country_data["year"].iloc[0]  # Year of first measurement
#         start_co2 = country_data["co2_rolling"].iloc[0]
#         year_end = country_data["year"].iloc[-1]  # Year of last measurement
#         pop_start = country_data["population"].iloc[0]  # population in year of first measurement
#         pop_end = country_data["population"].iloc[-1]  # population in year of last measurement
#         end_co2 = country_data["co2_rolling"].tail(1)  # Last meaurement for CO2 output
#         difference_co2 = (end_co2 - start_co2) / end_co2 * 100  # Percentage of difference in output between the start value and the last measured value
#         start_co2_capita = country_data["co2_capita_rolling"].iloc[0]  # first meaurement for CO2 output per capita
#         end_co2_capita = country_data["co2_capita_rolling"].iloc[-1]  # Last meaurement for CO2 output per capita
#         difference_co2_capita = (end_co2_capita - start_co2_capita) / end_co2_capita * 100  # Percentage of difference in output per capita between the start value and the last measured value
#         difference_pop = (pop_end - pop_start)/ pop_end * 100  # Percentage of difference in population

#         row = {"Country": country,
#                "Population change [%]": difference_pop,
#                "CO2 difference [%]" : difference_co2,
#                "CO2 difference per capita [%]" : difference_co2_capita
#                }
#         df_row = pd.DataFrame(row)
#         df_co2_difference = pd.concat([df_co2_difference, df_row], axis = 0)
#     return(df_co2_difference)

# df_co2_difference = co2_difference()

# %% [markdown]
# ### Determin top 5 best preformers for both co2 difference as for CO2 per capita difference

# %%
co2_difference_top_5_percentage = df_co2_difference.nsmallest(5, "CO2 difference [%]").sort_values("CO2 difference [%]", ascending = True)
co2_capita_difference_top_5_percentage = df_co2_difference.nsmallest(5, "CO2 difference per capita [%]").sort_values("CO2 difference per capita [%]", ascending = True)

# %% [markdown]
# ### Vizualize top 5

# %%
fig, ax = plt.subplots()
x = co2_difference_top_5_percentage["Country"]
y = co2_difference_top_5_percentage["CO2 difference [%]"]
y1 = co2_difference_top_5_percentage["Population change [%]"]
ax.bar(x,y, label = "CO2")
ax.bar(x,y1, label = "Population")
ax.set_xlabel("Country")
ax.set_ylabel("Change [%]")
ax.legend()
plt.xticks(rotation = 45, ha = "right", rotation_mode = "anchor")
plt.savefig("graph_reduction_%.png", transparent = False, facecolor = "white", bbox_inches = "tight")

display("Top 5 countries for CO2 reduction [%]")
# Out:
# 'Top 5 countries for CO2 reduction [%]'

# %%
fig, ax = plt.subplots()
x = co2_capita_difference_top_5_percentage["Country"]
y = co2_capita_difference_top_5_percentage["CO2 difference per capita [%]"]
y1 = co2_difference_top_5_percentage["Population change [%]"]

ax.bar(x,y, label = "CO2 per capita")
ax.bar(x,y1, label = "Population")
ax.set_xlabel("Country")
ax.set_ylabel("Change [%]")
# ax.set_title("Top 5 countries for CO2 reduction per capita [%]")
ax.legend()
plt.xticks(rotation = 45, ha = "right", rotation_mode = "anchor")
plt.savefig("graph_reduction_capita_%.png", transparent = False, facecolor = "white", bbox_inches = "tight")

display("Top 5 countries for CO2 reduction per capita [%]")
# Out:
# 'Top 5 countries for CO2 reduction per capita [%]'

# %% [markdown]
# Determine top 3 best performing countries. (appear in both graphs)

# %%
best_performing = pd.merge(co2_capita_difference_top_5_percentage, co2_difference_top_5_percentage, how='inner', left_on='Country', right_on='Country')

best_performing_1 =  best_performing.iloc[0, 0]
best_performing_2 = best_performing.iloc[1,0]
best_performing_3 = best_performing.iloc[2,0]
display(best_performing_1, best_performing_2, best_performing_3)
# display(best_performing_2)
# Out:
# 'Curacao'
# 'Aruba'
# 'Venezuela'

# %% [markdown]
# ## 3.Which non-fossil fuel energy technology will have the best price in the future?

# %% [markdown]
# ### Visualize costs over the years.
#
# Assumption is made that there are no more influences off tax and/ or subsidiary measures.

# %%
display(f"Levelized cost of energy by technology for the world")
fig, ax = plt.subplots()

sources = df_energy_cost_world.columns[3:]
years = df_energy_cost_world.iloc[:,2]
values = df_energy_cost_world.iloc[:, 3:]

plt.plot(years, values)
ax.legend(sources, bbox_to_anchor = (1, 0.7))

ax.set_ylabel("Cost [$/kWh]")
ax.set_xlabel("Year")

plt.show()
# Out:
# 'Levelized cost of energy by technology for the world'

# %% [markdown]
# ### Extrapolate with KNN

# %%
# extrapolate data with KNNearest
def extrapolate(source):
  df_cost_extrapolated_knn = df_energy_cost_world.copy()
  df_source = df_cost_extrapolated_knn[["Year", source]]
  df_source = df_source.dropna()
  range_years =  range(2022,2041) # not specified how far in the future
  for y in range_years:
      row = {"Year" : [y]}
      df_row = pd.DataFrame(row)
      df_source = pd.concat([df_source, df_row], axis = 0)
      imputer = KNNImputer(n_neighbors=5) # 5 = standard value
      df_source = imputer.fit_transform(df_source)
      df_source = pd.DataFrame(df_source, columns = ["Year", source])

  return (df_source)

# produce different extrapolated dataframes
bio = (extrapolate("Bioenergy levelized cost of energy"))
geo = (extrapolate("Geothermal levelized cost of energy"))
offshore = (extrapolate("Offshore wind levelized cost of energy"))
solar_voltaic = (extrapolate("Solar photovoltaic levelized cost of energy"))
concentrated_solar = (extrapolate("Concentrated solar power levelized cost of energy"))
hydropower = (extrapolate("Hydropower levelized cost of energy"))
onshore = (extrapolate("Onshore wind levelized cost of energy"))

# merge the diffent dataframes
dataframes_sources = [bio, geo, offshore, solar_voltaic, concentrated_solar, hydropower, onshore,]
df_cost_extrapolated_knn = reduce(lambda  left,right: pd.merge(left,right,on=['Year'],
                                            how='outer'), dataframes_sources)

# Sort dataframe on year
df_cost_extrapolated_knn = df_cost_extrapolated_knn.sort_values(by = ["Year"])

# %%
# visualize extrapolated prices during the years
fig, ax = plt.subplots()

original_data = df_cost_extrapolated_knn.loc[df_cost_extrapolated_knn["Year"] < 2022]
extrapolated = df_cost_extrapolated_knn.loc[df_cost_extrapolated_knn["Year"] >= 2022]

handles = ["Bioenergy", "Bioenergy extrapolated",
           "Geothermal", "Geothermal extrapolated",
           "Offshore wind", "Offshore wind extrapolated",
           "Solar voltaic", "Solar voltaic extrapolated",
           "Concentrated solar", "Concentrated solar extrapolated",
           "Hydropower", "Hydropower extrapolated",
           "Onshore wind", "Onshore wind extrapolated"]
#Bioenergy
ax.plot (original_data.iloc[:,0], original_data.iloc[:, 1:2], "blue")
ax.plot (extrapolated.iloc[:,0], extrapolated.iloc[:, 1:2], "blue", marker = ".")
# Geothermal
ax.plot (original_data.iloc[:,0], original_data.iloc[:, 2:3], "orange")
ax.plot (extrapolated.iloc[:,0], extrapolated.iloc[:, 2:3], "orange", marker = ".")
# Offshore wind
ax.plot (original_data.iloc[:,0], original_data.iloc[:, 3:4], "green")
ax.plot (extrapolated.iloc[:,0], extrapolated.iloc[:, 3:4], "green", marker = ".")
# Solar voltaic
ax.plot (original_data.iloc[:,0], original_data.iloc[:, 4:5], "red")
ax.plot (extrapolated.iloc[:,0], extrapolated.iloc[:, 4:5], "red", marker = ".")
# Concentrated solar
ax.plot (original_data.iloc[:,0], original_data.iloc[:, 5:6], "purple")
ax.plot (extrapolated.iloc[:,0], extrapolated.iloc[:, 5:6], "purple", marker = ".")
# Hydropower
ax.plot (original_data.iloc[:,0], original_data.iloc[:, 6:7], "brown")
ax.plot (extrapolated.iloc[:,0], extrapolated.iloc[:, 6:7], "brown", marker = ".")
# Onshore wind
ax.plot (original_data.iloc[:,0], original_data.iloc[:, 7:8], "magenta")
ax.plot (extrapolated.iloc[:,0], extrapolated.iloc[:, 7:8], "magenta", marker = ".")

# plt.plot(years, values)
ax.legend(handles, bbox_to_anchor = (1, 0.9))

ax.set_ylabel("Cost [$/kWh]")
ax.set_xlabel("Year")

plt.savefig("graph_extrapolated_costs_knn.png", transparent = False, facecolor = "white", bbox_inches = "tight")

display(f"Levelized cost of energy by technology for the world extrapolated with KNN.")
# Out:
# 'Levelized cost of energy by technology for the world extrapolated with KNN.'

# %% [markdown]
# There is a "strange" hub in the graph between actual data and extrapolated data.

# %% [markdown]
# ### extrapolate def with trendline
#
# there are ways used to extrapolate with a trendline.
# 1) mean value trendline
# 2) linear trendline
# 3) second degree polynomal trendline

# %%
def cost_extrapolated(degrees, extrapolate_till):
    # find variable names
    df_data = df_energy_cost_world.drop(["Entity", "Code", "Year"], axis = 1)
    variables = df_data.columns

    # Determine period for extrapolation
    range_years =  range(2022, (extrapolate_till +1))

    # final dataframe
    df_forecast = pd.DataFrame(columns = ["Year"])

    # for every variable:
    for column_name in variables:
        # make df
        df_energy = df_energy_cost_world[["Year",
                                          column_name]]
        # drop empty data
        df_energy = df_energy.dropna()
        column_trend = column_name + ", trend"
        x = df_energy["Year"]
        y = df_energy[column_name]
        z = np.polyfit(x, y, degrees)
        p = np.poly1d(z)
        df_energy[column_name + ", trend"] = p(x)
        df_forecast = pd.merge(df_forecast, df_energy, on = "Year", how = "outer").sort_values(["Year"])

        # # Extend dataframe for extrapolation
        for year in range_years:
            z = np.polyfit(x, y, degrees)
            p = np.poly1d(z)
            column_trend = column_name + ", trend"
            row = {"Year" : [year],
                  column_trend : [p(year)]}
            df_row = pd.DataFrame(row)
            df_energy = pd.concat([df_energy, df_row], axis = 0)
        df_energy = df_energy.drop(column_name, axis =1)

        df_forecast = df_forecast.drop(column_name + ", trend", axis =1)

        # Add data to df_forecast
        df_forecast = pd.merge(df_forecast, df_energy, on = "Year", how = "outer")
        df_forecast = df_forecast.drop(column_name, axis =1)
        # Sort forecast to Year
        df_forecast = df_forecast.sort_values("Year")
    return(df_forecast)

# %%
def cost_plot(df_extrapolated, extrapolation_type):
    fig, ax = plt.subplots()

    # Plot forecast/ extrapolated data
    df_data = df_extrapolated.drop(["Year"], axis = 1)
    variables = df_data.columns

    for name in variables:
        x = df_extrapolated["Year"]
        y = df_extrapolated[name]
        ax.plot(x,y)

    df_data = df_energy_cost_world.drop(["Entity", "Code", "Year"], axis = 1)
    variables = df_data.columns

    # Scatter actual data
    for name in variables:
        x = df_energy_cost_world["Year"]
        y = df_energy_cost_world[name]
        ax.scatter(x,y, marker = ".")

    handles =  variables.str.replace(" levelized cost of energy", "")
    ax.legend(handles, bbox_to_anchor = (1, 0.9))

    ax.set_ylabel("Cost [$/kWh]")
    ax.set_xlabel("Year")
    title = f"""Levelized costs per energy source for the world, {extrapolation_type} extrapolated till {df_extrapolated["Year"].max()}"""  # Title not encoded in graph for PDF report application
    figure_name = "graph_extrapolated_costs_" + extrapolation_type + ".png"
    plt.savefig(figure_name, transparent = False, facecolor = "white", bbox_inches = "tight")
    return(title)

# %% [markdown]
# ####Extrapolate with mean trendline

# %%
df_forecast_0 = cost_extrapolated(0, 2030)
cost_plot(df_forecast_0, "Mean")
# Out:
# 'Levelized costs per energy source for the world, Mean extrapolated till 2030'

# %% [markdown]
# ####Extrapolate with linear trendline

# %%
df_forecast_lin = cost_extrapolated(1, 2030)
cost_plot(df_forecast_lin, "lineair")
# Out:
# 'Levelized costs per energy source for the world, lineair extrapolated till 2030'

# %% [markdown]
# ####Extrapolate with second degree polynome trendline

# %%
df_forecast_pol2 = cost_extrapolated(2, 2030)
cost_plot(df_forecast_pol2, "second degree polynome")
# Out:
# 'Levelized costs per energy source for the world, second degree polynome extrapolated till 2030'

# %% [markdown]
# ### Extrapolate with exponential regression

# %%
# find variable names
df_data = df_energy_cost_world.drop(["Entity", "Code", "Year"], axis = 1)
variables = df_data.columns

# final dataframe
df_forecast_exp = pd.DataFrame(columns = ["Year"])

# for every variable:
for column_name in variables:
    df_energy = df_energy_cost_world[["Year",
                                      column_name]]
    # drop empty rows
    df = df_energy.dropna()

    # Determine period for extrapolation
    range_years =  range(2022,2031) # not specified how far in the future

    # Make copy of dataframe
    df1 = df.copy()

    # Add calculation columns
    df1['t-1'] = 0.00
    df1['t-2'] = 0.00
    df1['t-3'] = 0.00

    # Find index numbers for different columns
    index_column = df1.columns.get_loc(column_name)
    index_t1 = df1.columns.get_loc("t-1")
    index_t2 = df1.columns.get_loc("t-2")
    index_t3 = df1.columns.get_loc("t-3")

    # Determine column length of original dataframe
    length = len(df1)

    # Determine column length of exrapolated dataframe
    length2 = length + len(range_years)

    # Fill calculation columns
    for i in range(1,(len(df1[column_name]))):
        df1.iloc[i ,index_t1] = df1.iloc[(i-1), index_column]
        df1.iloc[i ,index_t2] = df1.iloc[(i-1), index_t1]
        df1.iloc[i ,index_t3] = df1.iloc[(i-1), index_t2]

    # Calculate interval
    xval=df1[1:length][['t-1','t-2','t-3']]
    yval=df1[1:length][[column_name]]

    # Define model
    model = skl.LinearRegression()
    model.fit(xval,yval)

    # Define prection formula
    xval1 = df1[:length][['t-1','t-2','t-3']]
    pred = model.predict(xval1)
    pred1 = pd.DataFrame(pred, columns = ['pred'])
    pred1 = pd.DataFrame(pred, columns = ['pred'])

    # Add forecast column
    forecast = column_name + ", forecast fit"
    df1[forecast] = 0.00
    # Determine index forecast column
    index_forecast = df1.columns.get_loc(forecast)

    # Add prediction values for known values
    for i in range(0,(len(pred1['pred']))):
        df1.iloc[i, index_forecast] = pred1.iloc[i, 0]

    # Extend dataframe for extrapolation
    for y in range_years:
        row = {"Year" : [y],
              "t-1" : [0.00],
              "t-2" : [0.00],
              "t-3" : [0.00],
              forecast : [0.00],
              column_name : [0.00]}
        df_row = pd.DataFrame(row)
        df1 = pd.concat([df1, df_row], axis = 0)
    # Replace first value with None to extract strange values
    df1.iloc[0, index_forecast] = None

    # Extrapolate data
    for i in range((length-3),(length2-3)):
        df1.iloc[(i+3), index_forecast] = model.intercept_[0] + model.coef_[0][0] * df1.iloc[(i+2), index_column] + model.coef_[0][1] * df1.iloc[(i+1), index_column] + model.coef_ [0][2] * df1.iloc[(i), index_column]
        df1.iloc[(i+3), index_column] = df1.iloc[(i+3), index_forecast]

    # Drop calculation columns and original data (keep only forecast column)
    df1.drop(['t-1','t-2','t-3', column_name],axis=1,inplace=True)

    # Add data to df_forecast
    df_forecast_exp = pd.merge(df_forecast_exp, df1, on = "Year", how = "outer")
    # Sort forecast to Year
    df_forecast_exp = df_forecast_exp.sort_values("Year")

# display(df_forecast)

# %% [markdown]
# Visualize forecast

# %%
cost_plot(df_forecast_exp, "exponential")
# Out:
# 'Levelized costs per energy source for the world, exponential extrapolated till 2030'

# %% [markdown]
# ### best fitted extrapolations

# %% [markdown]
# None of the variables have a good fitted mean trendline.
#
#
# The following variables appear to have a good fit with the lineair trendline
# - hydropower
#
#
# The following variables appear to have a good fit with the second degree polynomal trendline
#
# - Concentrated solar power
# - Offshore wind
#
#
# The remaining variables are best fitted by exponential regression.

# %%
df_forecast_a = df_forecast_pol2[["Year",
                                  "Concentrated solar power levelized cost of energy, trend",
                                  "Offshore wind levelized cost of energy, trend"]]
df_forecast_b = df_forecast_exp[["Year",
                                 "Bioenergy levelized cost of energy, forecast fit",
                                 "Geothermal levelized cost of energy, forecast fit",
                                 "Solar photovoltaic levelized cost of energy, forecast fit",
                                 "Onshore wind levelized cost of energy, forecast fit"]]
df_forecast_c = df_forecast_lin[["Year",
                                 "Hydropower levelized cost of energy, trend"]]

df_forecast_d = pd.merge(df_forecast_a, df_forecast_b, on = "Year", how = "outer").sort_values(["Year"])

df_forecast = pd.merge(df_forecast_d, df_forecast_c, on = "Year", how = "outer").sort_values(["Year"])

df_forecast = df_forecast[["Year",
                           "Bioenergy levelized cost of energy, forecast fit",
                           "Geothermal levelized cost of energy, forecast fit",
                           "Offshore wind levelized cost of energy, trend",
                           "Solar photovoltaic levelized cost of energy, forecast fit",
                           "Concentrated solar power levelized cost of energy, trend",
                           "Hydropower levelized cost of energy, trend",
                           "Onshore wind levelized cost of energy, forecast fit"]]
df_forecast.columns
# Out:
# Index(['Year', 'Bioenergy levelized cost of energy, forecast fit',
#        'Geothermal levelized cost of energy, forecast fit',
#        'Offshore wind levelized cost of energy, trend',
#        'Solar photovoltaic levelized cost of energy, forecast fit',
#        'Concentrated solar power levelized cost of energy, trend',
#        'Hydropower levelized cost of energy, trend',
#        'Onshore wind levelized cost of energy, forecast fit'],
#       dtype='object')

# %%
cost_plot(df_forecast, "")
# Out:
# 'Levelized costs per energy source for the world,  extrapolated till 2030'

# %% [markdown]
# ###Find 3 expected cheapest energy sources

# %%
df_cheapest = df_forecast.tail(1)
df_cheapest.columns = df_cheapest.columns.str.replace(" levelized cost of energy, forecast fit", "")
df_cheapest.columns = df_cheapest.columns.str.replace(" levelized cost of energy, trend", "")
last_extrapolated_year = df_cheapest.iloc[0,0]

df_cheapest = df_cheapest.transpose()
df_cheapest = df_cheapest.sort_values(47).head(3)

display(f"""For the year {last_extrapolated_year} the next three energy sources are believed to be the best priced:""", f"""1. {df_cheapest.index[0]}""", f"""2. {df_cheapest.index[1]}""", f"""3. {df_cheapest.index[2]}""")
# Out:
# 'For the year 2030 the next three energy sources are believed to be the best priced:'
# '1. Offshore wind'
# '2. Onshore wind'
# '3. Concentrated solar power'

# %% [markdown]
# # PDF report
#
# if you place the code into a folder on the computer, and run it, a PDF report will be placed into the same folder.

# %%
class PDF(FPDF):
    def header(self):
        # Logo
        # self.image('logo_pb.png', 10, 8, 33)
        # Arial bold 15
        self.set_font('Arial', 'B', 15)
        # Move to the right
        self.cell(80)
        # Title
        self.cell(30, 10, "", 0, 0, 'C')
        # Line break
        self.ln(20)
    # Page footer
    def footer(self):
        if self.page_no() != 1:
          # Go to 1.5 cm from bottom
          self.set_y(-15)
          # Select Arial italic 8
          self.set_font('Arial', 'I', 8)
          # Print centered page number
          self.cell(0, 10, 'Page %s' % self.page_no(), 0, 0, 'C')

# Origin of pdf
pdf = PDF("P", "mm", "A4")

# Add first page to pdf
pdf.add_page()

# margin
margin = 25

# page with (A4)
pw = 210 - (2 * margin)

# Cell height
ch = 5


# Doc title
pdf.set_font("Arial", "B", 28)
pdf.cell(w = 0, h = 200, txt = "CO2 emisions", ln = 2, align= "C")

# Doc date
pdf.set_font("Arial", "", 12)
pdf.cell(w = pw/2, h = ch, txt = "", ln = 0)
pdf.cell(w = pw/4, h = ch, txt = "Date:    ", ln = 0, align = "R")
pdf.cell(w = pw/4, h = ch, txt = "14-10-2023", ln = 1)

# Doc author
pdf.set_font("Arial", "", 12)
pdf.cell(w = pw/2, h = ch, txt = "", ln = 0)
pdf.cell(w = pw/4, h = ch, txt = "Author: ", ln = 0, align = "R")
pdf.cell(w = pw/4, h = ch, txt = "Petra Hartman", ln = 1)

# Introduction
pdf.add_page()
pdf.set_font("Arial", "B", 14)
pdf.cell(w = 0 , h = ch, txt = "Introduction", ln=1)
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = """This is a report regarding the CO2 emissions. Goal of this report is to answer the following questions:
1.\tWhat is the biggest predictor of a large CO2 output per capita of a country?
2.\tWhich countries are making the biggest strides in decreasing CO2 output?
3.\tWhich non-fossil fuel energy technology will have the best price in the future?

In this report you will find the method used to achieve these results, the results and the conclusion drawn from these results.

""")

# Method
pdf.set_font("Arial", "B", 14)
pdf.cell(w = 0 , h = ch, txt = """Method""", ln=1)

# Method 1. Biggest predictor
pdf.set_font("Arial", "B", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = "What is the biggest predictor of a large CO2 output per capita of a country?")
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""To determine the biggest predictors for a high CO2 output per capita for a country the decision is made to only use the CO2 emissions that are available per capita. Exeption is the GDP that will be converted to the GDP per capita.
1)\tCheck for outliers and replace by mean if present.
2)\tCheck if the variables are distributed normaly with the Shapiro-Wilk test.
3)\tIf the variables are not distributed normaly: normalize the data.
4)\tDetermine the Pearson correlation coefficient and corresponding P-value for all factors versus the {df_pearsonr.iloc[0, 0]}.
5)\tExclude all Pearson correlation coefficients with a P-value higher than 0.05%.
6)\tDetermine the 3 variables that have a high correlation to the {df_pearsonr.iloc[0, 0]}. Meaning that when the variable has a high value, the {df_pearsonr.iloc[0, 0]} has a high value as well.
""")

# Method 2. Biggest strides in decreasing CO2 output
pdf.set_font("Arial", "B", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = "\nWhich countries are making the biggest strides in decreasing CO2 output?")
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""To determine the countries that made the biggest strides in reducing the CO2 output the decision is made to only use the relative values of CO2 emission. These emissions are exluding land-use change and emissions embedded in traded goods. This to make the data objective and insensitive for the size of the country or population of the country.
The following steps will be taken:
1)\tCheck for outliers and replace by mean if present.
2)\tDetermine and visualise the cummulative CO2 output and the number contributing countries.
3)\tDetermine the CO2 output per country. This is done by formula:
\t\t[CO2 output] = ([CO2 output end period] - [CO2 output start value]) / [CO2 output end period] *100%.
4)\tDetermine the relative CO2 output per capita. This is done by formulas:
\t\t[CO2 output per capita] = ([CO2 output] * 1000000000) / [Population].
\t\t[Relative CO2 output per capita] = [CO2 output per capita end] - [CO2 output per capita start value] / [CO2 output per capita end] * 100
5)\tVisualize the best 5 performing countries of both the relative CO2 output as the relative CO2 output per capita.
6)\tThe countries that are in both conditions the best performing are the countries that made the biggest strides in reducing the CO2 output.
""")

# Method 3.
pdf.set_font("Arial", "B", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = "\nWhich non-fossil fuel energy technology will have the best price in the future?")
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = """To determine which non-fossil fuel energy technology will have most likely the best price in the future the curernt available data for the several types of energy will be used.
The following steps will be taken:
1)\tExtrapolate the available data of levelized energy cost (global scale).
2)\tPlot the original and extrapolated data in one graph
3)\tDetermine the 3 expected lowest priced energy sources for the future

""")

# Results header
pdf.set_font("Arial", "B", 14)
pdf.cell(w = 0 , h = ch, txt = "Results", ln=1)

# Results 1. Biggest predictor.
pdf.set_font("Arial", "B", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = "What is the biggest predictor of a large CO2 output per capita of a country?")
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""At first the data is checked for the normal distrubution according to the Shapiro-Wilkes test, the results are shown in table 1.1.""")
pdf.set_font("Arial", "", 8)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""Table 1.1: Results of the Shapiro-Wilk test.""")
# Table Header
pdf.set_font('Arial', 'B', 11)
pdf.cell(w=pw/4+10, h=ch, txt='Variable', border=1, ln=0, align='C')
pdf.cell(w=pw/4, h=ch, txt='Shapiro', border=1, ln=0, align='C')
pdf.cell(w=pw/4, h=ch, txt='P-value', border=1, ln=0, align='C')
pdf.cell(w=pw/4, h=ch, txt='Normal distributed', border=1, ln=1, align='C')
# Table contents
pdf.set_font('Arial', '', 8)
for i in range(0, len(df_shapiro)):
    pdf.cell(w=pw/4+10, h=ch,
             txt=df_shapiro["Variable"].iloc[i],
             border=1, ln=0, align='right')
    pdf.cell(w=pw/4, h=ch,
             txt=df_shapiro["Shapiro"].iloc[i].astype(str),
             border=1, ln=0, align='C')
    pdf.cell(w=pw/4, h=ch,
             txt=df_shapiro["P-value"].iloc[i].astype(str),
             border=1, ln=0, align='C')
    pdf.cell(w=pw/4, h=ch,
             txt=df_shapiro["Normal distributed"].iloc[i],
             border=1, ln=1, align='C')

pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""None of the variables are distributed normally. Since this is needed for the determination of the correlation betweeen variables, the data will be normalized by use of the cube root. This will make the data closer to the normal distribution, but not necessarely normaly distributed.
Graph 1.1 shows an example of a variable before and after normalizing.""")

pdf.set_font("Arial", "", 8)
pdf.image("histograms_original_normalized.png", x=10, w=80, h=0)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""Graph 1.1 Original and normalized data for coal CO2 (per capita)""")

pdf.add_page()
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""For the normalized data the correlation between the {df_pearsonr.iloc[0, 0]} and other variables is determined according to the Pearson correlation. The variables that have a correlation are plotted in graph 1.2.""")

pdf.set_font("Arial", "", 8)
pdf.image("correlating_factors.png", x=10, w=100, h=0)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""Graph 1.2 correlation with {df_pearsonr.iloc[0,0]}.""")
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""The three variables with the highest correlation for predicting a high CO2 output are:
1)\t{correlating_factor_1}
2)\t{correlating_factor_2}
3)\t{correlating_factor_3}.""")

# Results 2. Biggest strides in decreasing CO2 output
pdf.set_font("Arial", "B", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = "\nWhich countries are making the biggest strides in decreasing CO2 output?")
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""First the global trend for the CO2 output is visualized in graph 2.1. For this graph the data of all countries that presented measurements was added together.""")
pdf.set_font("Arial", "", 8)
pdf.image("total_emission_per_year.png", x=10, w=100, h=0)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""Graph 2.1: Total output of CO2 per year and the number of contributing countries""")
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""Together it is seen that the CO2 output is rising almost each year, even after the number of contributing countries has stabilized.
The period ver which the data is analyzed is {first_year} till {last_year} because in this period the same {max_countries_year} of countries contributed in the data. The assumption is  made that all data is supplied in the same way for each country and each year.""")

pdf.add_page()
pdf.multi_cell(w = 0, h = ch,
               txt = f"""Next the reduction per country is calculated and visualized for the best 5. In order to even out the size of the country the data is given in CO2 output per country [%] (graph 2.2) and CO2 output per capita of a country [%]""")
pdf.set_font("Arial", "", 8)
pdf.image("graph_reduction_%.png", x=10, w=80, h=0)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""Graph 2.2: The 5 best performing countries on CO2 reduction per capita.""")
pdf.set_font("Arial", "", 8)
pdf.image("graph_reduction_capita_%.png", x=10, w=80, h=0)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""Graph 2.3: The 5 best performing countries on CO2 reduction.""")
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""The best performing countries in CO2 output reduction are:
-\t{best_performing_1}
-\t{best_performing_2}
-\t{best_performing_3}
               """)

# results 3.
pdf.add_page()
pdf.set_font("Arial", "B", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = "Which non-fossil fuel energy technology will have the best price in the future?")
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""To determine the 3 best prised non-fossil fuel sources in {last_extrapolated_year} the data was extrapolated in different ways. Since not all data can be extrapolated in the same way different methods were used. In graph 3.1 the original and best form of extrapolated data for the several energy technologies are plotted.""")
pdf.set_font("Arial", "", 8)
pdf.image("graph_extrapolated_costs_.png", x=10, w=100, h=0)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""Graph 3.1: Original and extrapolated data for the different energy technologies.""")
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""The three non-fossil energy technologies that have most likely the lowest price in the future are:
1)\t{df_cheapest.index[0]}
2)\t{df_cheapest.index[1]}
3)\t{df_cheapest.index[2]}

""")

# Conclusion header
pdf.set_font("Arial", "B", 14)
pdf.cell(w = 0 , h = ch, txt = "Conclusions", ln=1)

# Conclusion 1. Biggest predictor
pdf.set_font("Arial", "B", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = "What is the biggest predictor of a large CO2 output per capita of a country?")
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""The three variables with the highest correlation for predicting a high CO2 output are:
1)\t{correlating_factor_1}
2)\t{correlating_factor_2}
3)\t{correlating_factor_3}.
""")

# Conclusion 2. Biggest strides in decreasing CO2 output
pdf.set_font("Arial", "B", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = "\nWhich countries are making the biggest strides in decreasing CO2 output?")
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""The best performing countries in CO2 output reduction are:
-\t{best_performing_1}
-\t{best_performing_2}
-\t{best_performing_3}
""")

# Conclusion 3.
pdf.set_font("Arial", "B", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = "\nWhich non-fossil fuel energy technology will have the best price in the future?")
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = f"""The three non-fossil energy technologies that have most likely the lowest price in the future are:
1)\t{df_cheapest.index[0]}
2)\t{df_cheapest.index[1]}
3)\t{df_cheapest.index[2]}

""")

# Sources
pdf.set_font("Arial", "B", 14)
pdf.multi_cell(w = 0, h = ch,
               txt = "Sources")
pdf.set_font("Arial", "", 11)
pdf.multi_cell(w = 0, h = ch,
               txt = """https://ourworldindata.org/co2-and-greenhouse-gas-emissions
https://github.com/owid/co2-data
https://wikistatistiek.amc.nl/index.php/KEUZE_TOETS
https://data-affinity.nl/statistiek/sterkte-van-een-verband-bepalen.html
https://www.statology.org/normality-test-python/
https://ourworldindata.org/grapher/levelized-cost-of-energy
https://medium.com/@polanitzer/linear-extrapolation-in-python-forecast-the-future-revenues-of-a-company-73c162855743""")

# output:
pdf.output ("CO2_emissions.pdf", "F")
# Out:
# ''
